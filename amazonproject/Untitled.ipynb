# %%
import scrapy

# %%
metin = '''<div class="sg-row">
      
      <div class="sg-col-4-of-12 sg-col-4-of-16 sg-col sg-col-4-of-20"><div class="sg-col-inner">
        <div class="a-section a-spacing-none">
          





<span data-component-type="s-product-image" class="rush-component" data-component-id="9">
    
    <a class="a-link-normal s-no-outline" href="/Samsung-Factory-Unlocked-Smartphone-Pro-Grade/dp/B08FYV84JT/ref=sr_1_1?dchild=1&amp;keywords=phone&amp;qid=1608662423&amp;refinements=p_89%3ASamsung+Electronics&amp;s=wireless&amp;sr=1-1">
        <div class="a-section aok-relative s-image-fixed-height">
            
                
                
                    <img src="https://m.media-amazon.com/images/I/710vzk+ckcL._AC_UY218_.jpg" class="s-image" alt="Samsung Galaxy S20 FE 5G | Factory Unlocked Android Cell Phone | 128 GB | US Version Smartphone | Pro-Grade Camera, 30X Sp..." srcset="https://m.media-amazon.com/images/I/710vzk+ckcL._AC_UY218_.jpg 1x, https://m.media-amazon.com/images/I/710vzk+ckcL._AC_UY327_FMwebp_QL65_.jpg 1.5x, https://m.media-amazon.com/images/I/710vzk+ckcL._AC_UY436_FMwebp_QL65_.jpg 2x, https://m.media-amazon.com/images/I/710vzk+ckcL._AC_UY545_FMwebp_QL65_.jpg 2.5x, https://m.media-amazon.com/images/I/710vzk+ckcL._AC_UY654_FMwebp_QL65_.jpg 3x" data-image-index="0" data-image-load="" data-image-latency="s-product-image" data-image-source-density="1">
                
            
        </div>
    </a>
</span>

        </div>
      </div></div>

      <div class="sg-col-4-of-12 sg-col-8-of-16 sg-col-12-of-20 sg-col"><div class="sg-col-inner">
        
        <div class="sg-row">
          <div class="sg-col-4-of-12 sg-col-8-of-16 sg-col-12-of-20 sg-col"><div class="sg-col-inner">
            <div class="a-section a-spacing-none">
              




<h2 class="a-size-mini a-spacing-none a-color-base s-line-clamp-2">
    
    
        




<a class="a-link-normal a-text-normal" href="/Samsung-Factory-Unlocked-Smartphone-Pro-Grade/dp/B08FYV84JT/ref=sr_1_1?dchild=1&amp;keywords=phone&amp;qid=1608662423&amp;refinements=p_89%3ASamsung+Electronics&amp;s=wireless&amp;sr=1-1">
    
        
            
                <span class="a-size-medium a-color-base a-text-normal" dir="auto">Samsung Galaxy S20 FE 5G | Factory Unlocked Android Cell Phone | 128 GB | US Version Smartphone | Pro-Grade Camera, 30X Space Zoom, Night Mode | Cloud Red</span>
            
        
        
    
</a>

    
</h2>

            </div>
            
              <div class="a-section a-spacing-none a-spacing-top-micro">
                <div class="a-row a-size-small">


<span aria-label="4.5 out of 5 stars">
    






    
        <span class="a-declarative" data-action="a-popover" data-a-popover="{&quot;max-width&quot;:&quot;700&quot;,&quot;closeButton&quot;:false,&quot;position&quot;:&quot;triggerBottom&quot;,&quot;url&quot;:&quot;/review/widgets/average-customer-review/popover/ref=acr_search__popover?ie=UTF8&amp;asin=B08FYV84JT&amp;ref=acr_search__popover&amp;contextId=search&quot;}">
            
            <a href="javascript:void(0)" class="a-popover-trigger a-declarative"><i class="a-icon a-icon-star-small a-star-small-4-5 aok-align-bottom"><span class="a-icon-alt">4.5 out of 5 stars</span></i><i class="a-icon a-icon-popover"></i></a>
        </span>
    
    


</span>



<span aria-label="1,142">
    




<a class="a-link-normal" href="/Samsung-Factory-Unlocked-Smartphone-Pro-Grade/dp/B08FYV84JT/ref=sr_1_1?dchild=1&amp;keywords=phone&amp;qid=1608662423&amp;refinements=p_89%3ASamsung+Electronics&amp;s=wireless&amp;sr=1-1#customerReviews">
    
        
            
                <span class="a-size-base" dir="auto">1,142</span>
            
        
        
    
</a>

</span>
</div>
              </div>
            
          </div></div>
        </div>

        
        <div class="sg-row">
          
          <div class="sg-col-4-of-12 sg-col-4-of-16 sg-col sg-col-4-of-20"><div class="sg-col-inner">
            
              <div class="a-section a-spacing-none a-spacing-top-small">
                <div class="a-row a-size-base a-color-base">




<a class="a-size-base a-link-normal a-text-bold" href="/Samsung-Factory-Unlocked-Smartphone-Pro-Grade/dp/B08FYV84JT/ref=sr_1_1?dchild=1&amp;keywords=phone&amp;qid=1608662423&amp;refinements=p_89%3ASamsung+Electronics&amp;s=wireless&amp;sr=1-1">
    
        
        
            Cloud Red
        
    
</a>
</div>
              </div>
            
            
            
            
            
            
              <div class="a-section a-spacing-none a-spacing-top-mini">
                <div class="a-row"><div class="a-row">





<div class="aok-inline-block aok-align-center">
    
        
            <div class="a-section s-color-variation-image">
                <span class="a-declarative" data-action="a-tooltip" data-a-tooltip="{&quot;inlineContent&quot;:&quot;Cloud Green&quot;,&quot;position&quot;:&quot;triggerTop&quot;}">
                    





<span data-component-type="s-product-image" class="rush-component" data-component-id="10">
    
    <a class="a-link-normal s-no-outline" href="/Samsung-Factory-Unlocked-Smartphone-Pro-Grade/dp/B08FYVMRM5/ref=sr_1_1?keywords=phone&amp;qid=1608663416&amp;refinements=p_89%3ASamsung+Electronics&amp;s=wireless&amp;sr=1-1">
        <div class="a-section">
            
                
                
                    <img src="https://m.media-amazon.com/images/I/31E08r3vEcL._AC_US40_.jpg" class="s-image" alt="Cloud Green" srcset="https://m.media-amazon.com/images/I/31E08r3vEcL._AC_US40_.jpg 1x, https://m.media-amazon.com/images/I/31E08r3vEcL._AC_US60_FMwebp_QL65_.jpg 1.5x, https://m.media-amazon.com/images/I/31E08r3vEcL._AC_US80_FMwebp_QL65_.jpg 2.0000x" data-image-index="" data-image-load="" data-image-latency="s-product-image" data-image-source-density="1">
                
            
        </div>
    </a>
</span>

                </span>
            </div>
        
        
    
</div>






<div class="aok-inline-block aok-align-center">
    
        
            <div class="a-section s-color-variation-image">
                <span class="a-declarative" data-action="a-tooltip" data-a-tooltip="{&quot;inlineContent&quot;:&quot;Cloud Lavender&quot;,&quot;position&quot;:&quot;triggerTop&quot;}">
                    





<span data-component-type="s-product-image" class="rush-component" data-component-id="11">
    
    <a class="a-link-normal s-no-outline" href="/Samsung-Unlocked-Smartphone-Pro-Grade-Lavender/dp/B08FYTRF6J/ref=sr_1_1?keywords=phone&amp;qid=1608663416&amp;refinements=p_89%3ASamsung+Electronics&amp;s=wireless&amp;sr=1-1">
        <div class="a-section">
            
                
                
                    <img src="https://m.media-amazon.com/images/I/31itH8NFHXL._AC_US40_.jpg" class="s-image" alt="Cloud Lavender" srcset="https://m.media-amazon.com/images/I/31itH8NFHXL._AC_US40_.jpg 1x, https://m.media-amazon.com/images/I/31itH8NFHXL._AC_US60_FMwebp_QL65_.jpg 1.5x, https://m.media-amazon.com/images/I/31itH8NFHXL._AC_US80_FMwebp_QL65_.jpg 2.0000x" data-image-index="" data-image-load="" data-image-latency="s-product-image" data-image-source-density="1">
                
            
        </div>
    </a>
</span>

                </span>
            </div>
        
        
    
</div>






<div class="aok-inline-block aok-align-center">
    
        
            <div class="a-section s-color-variation-image">
                <span class="a-declarative" data-action="a-tooltip" data-a-tooltip="{&quot;inlineContent&quot;:&quot;Cloud Navy&quot;,&quot;position&quot;:&quot;triggerTop&quot;}">
                    





<span data-component-type="s-product-image" class="rush-component" data-component-id="12">
    
    <a class="a-link-normal s-no-outline" href="/Samsung-Factory-Unlocked-Smartphone-Pro-Grade/dp/B08FYTSXGQ/ref=sr_1_1?keywords=phone&amp;qid=1608663416&amp;refinements=p_89%3ASamsung+Electronics&amp;s=wireless&amp;sr=1-1">
        <div class="a-section">
            
                
                
                    <img src="https://m.media-amazon.com/images/I/31JBs+h6-BL._AC_US40_.jpg" class="s-image" alt="Cloud Navy" srcset="https://m.media-amazon.com/images/I/31JBs+h6-BL._AC_US40_.jpg 1x, https://m.media-amazon.com/images/I/31JBs+h6-BL._AC_US60_FMwebp_QL65_.jpg 1.5x, https://m.media-amazon.com/images/I/31JBs+h6-BL._AC_US80_FMwebp_QL65_.jpg 2.0000x" data-image-index="" data-image-load="" data-image-latency="s-product-image" data-image-source-density="1">
                
            
        </div>
    </a>
</span>

                </span>
            </div>
        
        
    
</div>






<div class="aok-inline-block aok-align-center">
    
        
        
            <div class="a-section s-color-variation-link">
                <span class="a-declarative" data-action="a-tooltip" data-a-tooltip="{&quot;inlineContent&quot;:&quot;See more colors&quot;,&quot;position&quot;:&quot;triggerTop&quot;}">
                    <div class="a-section a-spacing-mini a-spacing-top-mini">
                        




<a class="a-link-normal a-text-normal" href="/Samsung-Factory-Unlocked-Smartphone-Pro-Grade/dp/B08FYV84JT/ref=sr_1_1?dchild=1&amp;keywords=phone&amp;qid=1608662423&amp;refinements=p_89%3ASamsung+Electronics&amp;s=wireless&amp;sr=1-1">
    
        
            
                <span class="a-color-base s-align-text-bottom"><div class="a-box a-text-center"><div class="a-box-inner">+</div></div></span>
            
        
        
    
</a>

                    </div>
                </span>
            </div>
        
    
</div>
</div></div>
              </div>
            
            
              <div class="a-section a-spacing-none a-spacing-top-mini">
                







    <div class="a-section a-spacing-none">
        <a class="a-link-normal s-align-children-center s-no-underline" href="/Samsung-Factory-Unlocked-Smartphone-Pro-Grade/dp/B08FYV84JT/ref=cpf_sp_dsk_srpb_bgck?dchild=1&amp;keywords=phone&amp;qid=1608662423&amp;refinements=p_89%3ASamsung+Electronics&amp;s=wireless&amp;sr=1-1">
            <img alt="" src="https://m.media-amazon.com/images/I/216-OX9rBaL._SS72_.png" height="18" width="18">
            <span class="a-size-base s-cpf-badge" dir="auto">
                Climate Pledge Friendly
            </span>
        </a>
    </div>



<span class="a-declarative" data-action="s-cpf-popover" data-s-cpf-popover="{&quot;padding&quot;:&quot;medium&quot;,&quot;closeButton&quot;:false,&quot;closeButtonLabel&quot;:&quot;Close popup&quot;,&quot;name&quot;:&quot;cpf-popover-B08FYV84JT&quot;,&quot;activate&quot;:&quot;onmouseover&quot;,&quot;width&quot;:&quot;339&quot;,&quot;position&quot;:&quot;triggerBottom&quot;,&quot;popoverLabel&quot;:&quot;Sustainability certifications for this product&quot;}">
    <a href="javascript:void(0)" class="a-popover-trigger a-declarative s-no-underline s-cpf-badge s-align-children-center">
        
            
                
                <span class="a-size-base a-color-link" dir="auto">See 1 certification</span>
            
            
        
    <i class="a-icon a-icon-popover"></i></a>
</span>


<div class="a-popover-preload" id="a-popover-cpf-popover-B08FYV84JT">
    <div class="a-row a-spacing-base"><span class="a-size-base a-color-base" dir="auto">We’ve made it easier to discover products with sustainability certifications, as part of our commitment to help preserve the natural world. Time is fleeting.</span>




<a class="a-size-base a-link-normal" href="/b/ref=cpf_sp_dsk_srpo_lmlk?node=21221607011">
    
        
        
            Learn more
        
    
</a>
</div><div class="a-row"><span class="a-size-base a-color-tertiary a-text-bold" dir="auto">PRODUCT CERTIFICATION (1)</span></div>

    <div class="a-row s-cpf-popover-content">
        
            <div class="a-column a-span12 a-span-last">
                
                    <div class="a-row a-spacing-none s-align-children-center s-cpf-certification">
                        
                            <div class="s-cpf-certification-logo aok-inline-block">
                             
                                <a class="a-link-normal" href="/Samsung-Factory-Unlocked-Smartphone-Pro-Grade/dp/B08FYV84JT/ref=cpf_sp_dsk_srpo_cfar?dchild=1&amp;keywords=phone&amp;qid=1608662423&amp;refinements=p_89%3ASamsung+Electronics&amp;s=wireless&amp;sr=1-1#climatePledgeFriendly">
                                    <img alt="" src="https://m.media-amazon.com/images/I/21OXy0oJ8VL._SS160_.png" height="40px" width="40px">
                                </a>
                            </div>
                        
                        <div class="a-section s-cpf-no-margin-bottom aok-inline-block">
                            
                                
                                
                                    




<a class="a-link-normal" href="/Samsung-Factory-Unlocked-Smartphone-Pro-Grade/dp/B08FYV84JT/ref=cpf_sp_dsk_srpo_cfar?dchild=1&amp;keywords=phone&amp;qid=1608662423&amp;refinements=p_89%3ASamsung+Electronics&amp;s=wireless&amp;sr=1-1#climatePledgeFriendly">
    
        
        
            EPEAT
        
    
</a>

                                
                            
                            
                        </div>
                    </div>
                
            </div>
        
    </div>

    
</div>

              </div>
            
          </div></div>

          
          <div class="sg-col-4-of-12 sg-col-4-of-16 sg-col sg-col-8-of-20"><div class="sg-col-inner">
            
          </div></div>
        </div>

        
        <div class="sg-row">
          <div class="sg-col-16-of-20 sg-col sg-col-8-of-12 sg-col-12-of-16"><div class="sg-col-inner">
          </div></div>
        </div>

        
        <div class="sg-row">
          <div class="sg-col-16-of-20 sg-col sg-col-8-of-12 sg-col-12-of-16"><div class="sg-col-inner">
            
          </div></div>
        </div>
      </div></div>
    </div>'''

# %%
selector = scrapy.Selector(text = metin)

# %%
selector
# Out:
# <Selector xpath=None data='<html><body><div class="sg-row">\n    ...'>

# %%
selector.xpath('.//span[@class="a-size-medium a-color-base a-text-normal"]/text()').extract()
# Out:
# ['Samsung Galaxy S20 FE 5G | Factory Unlocked Android Cell Phone | 128 GB | US Version Smartphone | Pro-Grade Camera, 30X Space Zoom, Night Mode | Cloud Red']
